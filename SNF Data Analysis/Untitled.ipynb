# %%
# Importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import math

# Making NumPy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)

# %%
# Importing the dataset
dataset = pd.read_csv('data_corr.csv')

# Removing the year
dataset = dataset.drop('Year', axis='columns')

# %%
""" Checking the dataset for distribution of the data using the filter method (Pearson correlation)
Only 
"""

plt.figure(figsize=(12,10))
cor = dataset.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
dataset.corr().to_clipboard(excel=True)

# %%
# Correlation with output variable
cor_target = abs(cor["Energy Denied"])

# Selecting highly correlated features
relevant_features = cor_target[cor_target>0.5]
relevant_features
# Out:
# SAIDI                        0.977250
# Population                   0.823432
# Power Generated              0.832453
# GDP per Capita               0.617729
# Availability TT1PP           0.867314
# Availability CENIT           0.527709
# Availability TT2PP           0.637441
# Availability Sunon Asogli    0.561091
# Availability MRP             0.579419
# Availability AKSA            0.573284
# % Hydro                      0.916529
# % Thermal                    0.913222
# % Renewable                  0.503128
# Energy Denied                1.000000
# Name: Energy Denied, dtype: float64
